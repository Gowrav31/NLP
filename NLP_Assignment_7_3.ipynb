# %% [markdown]
# <a href="https://colab.research.google.com/github/Gowrav31/NLP/blob/main/NLP_Assignment_7_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_excel("/content/Book1.xlsx")

# %%
display (data)
# Out:
#                    STATEMENT
# 0     I like playing cricket
# 1        I like playing pubg
# 2    I like playing football
# 3  I like playing car racing

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd

documents = [D1, D2, D3, D4]


vectorizer = CountVectorizer(max_df=0.95, min_df=1, stop_words="english")

bow = vectorizer.fit_transform(documents)

feature_names = vectorizer.get_feature_names_out()

df_bow = pd.DataFrame(bow.toarray(), columns=feature_names)

print("Bag of Words (TF-IDF) Representation:")
print(df_bow)
# Out:
# Bag of Words (TF-IDF) Representation:
#    car  cricket  football  pubg  racing
# 0    0        1         0     0       0
# 1    0        0         0     1       0
# 2    0        0         1     0       0
# 3    1        0         0     0       1

# %%
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

cosine_sim_matrix = cosine_similarity(df_bow)

df_cosine_sim = pd.DataFrame(cosine_sim_matrix, index=[D1,D2,D3,D4], columns=[D1,D2,D3,D4])

print("Cosine Similarity Matrix:")
print(df_cosine_sim)
# Out:
# Cosine Similarity Matrix:
#                              I like playing  cricket  I like playing pubg   \
# I like playing  cricket                          1.0                   0.0
# I like playing pubg                              0.0                   1.0
# I like playing football                          0.0                   0.0
# I like playing car racing                        0.0                   0.0
#
#                              I like playing football    \
# I like playing  cricket                            0.0
# I like playing pubg                                0.0
# I like playing football                            1.0
# I like playing car racing                          0.0
#
#                              I like playing car racing
# I like playing  cricket                              0.0
# I like playing pubg                                  0.0
# I like playing football                              0.0
# I like playing car racing                            1.0

# %%
from sklearn.metrics import jaccard_score
import numpy as np
import pandas as pd

binary_bow = (df_bow > 0).astype(int)

num_documents = binary_bow.shape[0]
jaccard_sim_matrix = np.zeros((num_documents, num_documents))

for i in range(num_documents):
    for j in range(num_documents):
        vec_i = binary_bow.iloc[i]
        vec_j = binary_bow.iloc[j]

        intersection = np.sum(np.logical_and(vec_i, vec_j))
        union = np.sum(np.logical_or(vec_i, vec_j))

        if union == 0:
            jaccard_sim_matrix[i, j] = 0.0 # If both sets are empty, similarity is 0
        else:
            jaccard_sim_matrix[i, j] = intersection / union

df_jaccard_sim = pd.DataFrame(jaccard_sim_matrix, index=documents, columns=documents)

print("Jaccard Similarity Matrix:")
print(df_jaccard_sim)
# Out:
# Jaccard Similarity Matrix:
#                              I like playing  cricket  I like playing pubg   \
# I like playing  cricket                          1.0                   0.0
# I like playing pubg                              0.0                   1.0
# I like playing football                          0.0                   0.0
# I like playing car racing                        0.0                   0.0
#
#                              I like playing football    \
# I like playing  cricket                            0.0
# I like playing pubg                                0.0
# I like playing football                            1.0
# I like playing car racing                          0.0
#
#                              I like playing car racing
# I like playing  cricket                              0.0
# I like playing pubg                                  0.0
# I like playing football                              0.0
# I like playing car racing                            1.0

# %%
D1="I like playing  cricket"
D2="I like playing pubg "
D3="I like playing football  "
D4="I like playing car racing  "
import nltk
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
import numpy as np
import pandas as pd

try:
    nltk.data.find('corpora/wordnet')
except LookupError:
    nltk.download('wordnet')
try:
    nltk.data.find('tokenizers/punkt_tab')
except LookupError:
    nltk.download('punkt_tab')

def document_wordnet_similarity(doc1, doc2):
    tokens1 = word_tokenize(doc1.lower())
    tokens2 = word_tokenize(doc2.lower())

    synsets1 = [s for token in tokens1 for s in wordnet.synsets(token)]
    synsets2 = [s for token in tokens2 for s in wordnet.synsets(token)]

    if not synsets1 or not synsets2:
        return 0.0

    max_similarities = []
    for s1 in synsets1:
        max_sim_for_s1 = 0.0
        for s2 in synsets2:
            sim = s1.path_similarity(s2)
            if sim is not None and sim > max_sim_for_s1:
                max_sim_for_s1 = sim
        max_similarities.append(max_sim_for_s1)

    if max_similarities:
        return np.mean(max_similarities)
    else:
        return 0.0

documents = [D1, D2, D3, D4]

num_documents = len(documents)
wordnet_sim_matrix = np.zeros((num_documents, num_documents))

for i in range(num_documents):
    for j in range(num_documents):
        if i == j:
            wordnet_sim_matrix[i, j] = 1.0
        else:
            wordnet_sim_matrix[i, j] = document_wordnet_similarity(documents[i], documents[j])

df_wordnet_sim = pd.DataFrame(wordnet_sim_matrix, index=documents, columns=documents)

print("WordNet Similarity Matrix (Path Similarity):")
print(df_wordnet_sim)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# WordNet Similarity Matrix (Path Similarity):
#                              I like playing  cricket  I like playing pubg   \
# I like playing  cricket                     1.000000              0.959184
# I like playing pubg                         1.000000              1.000000
# I like playing football                     0.971212              0.968182
# I like playing car racing                   0.872241              0.872241
#
#                              I like playing football    \
# I like playing  cricket                       0.962585
# I like playing pubg                           1.000000
# I like playing football                       1.000000
# I like playing car racing                     0.874303
#
#                              I like playing car racing
# I like playing  cricket                         0.959609
# I like playing pubg                             1.000000
# I like playing football                         0.970455
# I like playing car racing                       1.000000
